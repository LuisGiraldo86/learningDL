# %% [markdown]
# # Experimenting with Deep Learning and Reuters dataset

# %% [markdown]
# # Reuters dataset. Experiment 1
#
# This first experiment consist in evaluate the performance of a NN with two hidden layers on the Reuters classification problem. We have selected `MlFlow` to track the performance variation an assess the models.

# %%
# imports
import os

import tensorflow as tf
import numpy as np
import mlflow

from mlflow.tracking import MlflowClient;
# Out:
# 2024-04-29 15:38:18.311015: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-29 15:38:18.314778: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-29 15:38:18.361542: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-29 15:38:19.561709: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# import local modules
import sys
sys.path.append('/mnt/0A2AAC152AABFBB7/sideProjects/deepLearning')
from deeplearning.deep_utils import reuters_model_three_layers

# %%
# Loading the Reuters dataset

(train_data, train_labels), (test_data, test_labels) = tf.keras.datasets.reuters.load_data(num_words=10000);

# %%
# Encoding the integer sequences via multi-hot encoding

def vectorize_sequences(sequences, dimension=10000):

    results = np.zeros((len(sequences), dimension))

    for i, sequence in enumerate(sequences):
        for j in sequence:
            results[i, j] = 1.
    return results

# vectorize training and test data

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# vectorize training and test labels

y_train = tf.keras.utils.to_categorical(train_labels)
y_test = tf.keras.utils.to_categorical(test_labels)

# Setting aside a validation set

x_val = x_train[:1000]
partial_x_train = x_train[1000:]
y_val = y_train[:1000]
partial_y_train = y_train[1000:]

# %%
# Initialize client and experiment

EXPERIMENT_NAME = "deepLearning_reuters_dataset"
client = MlflowClient()
mlflow.set_experiment(EXPERIMENT_NAME)
exp = client.get_experiment_by_name(EXPERIMENT_NAME)
# Out:
# 2024/04/29 15:38:22 INFO mlflow.tracking.fluent: Experiment with name 'deepLearning_reuters_dataset' does not exist. Creating a new experiment.

# %%
layer_units = [
    [64, 64, 46], [64, 32, 46], [128, 128, 46], [32, 32, 46], [8, 8, 46]
]

# %%
for units in layer_units:

    model, history = reuters_model_three_layers(
        units=units,
        activ_func="relu",
        X_train=partial_x_train,
        y_train=partial_y_train,
        X_val=x_val,
        y_val=y_val
    )

    hist_dict = history.history
    test_loss, test_accuracy = model.evaluate(x_test, y_test)

    with mlflow.start_run():
        mlflow.set_tag("model", "Base_0")
        mlflow.log_param("units_1st_layer", units[0])
        mlflow.log_param("units_2nd_layer", units[1])
        mlflow.log_param("hidden_activation", 'relu')
        mlflow.log_param("epochs", 9)
        mlflow.log_param("batch_size", 512)
        mlflow.log_metric("accuracy", test_accuracy)
        mlflow.log_metric("loss", test_loss)
# Out:
# Epoch 1/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.3127 - loss: 3.2601 - val_accuracy: 0.6090 - val_loss: 1.9225
# Epoch 2/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6501 - loss: 1.6862 - val_accuracy: 0.6800 - val_loss: 1.4107
# Epoch 3/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7312 - loss: 1.2228 - val_accuracy: 0.7320 - val_loss: 1.2044
# Epoch 4/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7926 - loss: 0.9740 - val_accuracy: 0.7620 - val_loss: 1.0962
# Epoch 5/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8191 - loss: 0.8399 - val_accuracy: 0.7880 - val_loss: 1.0133
# Epoch 6/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8503 - loss: 0.6977 - val_accuracy: 0.7900 - val_loss: 0.9649
# Epoch 7/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8851 - loss: 0.5673 - val_accuracy: 0.8020 - val_loss: 0.9324
# Epoch 8/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8971 - loss: 0.4906 - val_accuracy: 0.8100 - val_loss: 0.8917
# Epoch 9/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5854 - loss: 2.1515 - val_accuracy: 0.5920 - val_loss: 2.0082
# Epoch 6/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6107 - loss: 1.9038 - val_accuracy: 0.6030 - val_loss: 1.8323
# Epoch 7/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6194 - loss: 1.7309 - val_accuracy: 0.6070 - val_loss: 1.7021
# Epoch 8/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6250 - loss: 1.6088 - val_accuracy: 0.6090 - val_loss: 1.6081
# Epoch 9/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6370 - loss: 1.4797 - val_accuracy: 0.6120 - val_loss: 1.5433
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.6260 - loss: 1.5656

# %%
runs = mlflow.search_runs()
PATH_TO_RUNS = "/mnt/0A2AAC152AABFBB7/sideProjects/deepLearning/mlflow_runs"
runs.to_csv(
    os.path.join(PATH_TO_RUNS, "reuters_runs_1.csv")
)
runs
# Out:
#                              run_id       experiment_id    status  \
# 0  f8cadb40d1834860acedc8ad0d104d85  852056537141572214  FINISHED
# 1  3c317361783042b6bfdd4134e9a14703  852056537141572214  FINISHED
# 2  4a0d15ba59e64a50bbcd1a09a14e53b4  852056537141572214  FINISHED
# 3  372f37aac0674b8fad9ffe3c291e0f7d  852056537141572214  FINISHED
# 4  48805b853d714a85b449d11e7361052a  852056537141572214  FINISHED
#
#                                         artifact_uri  \
# 0  file:///mnt/0A2AAC152AABFBB7/sideProjects/deep...
# 1  file:///mnt/0A2AAC152AABFBB7/sideProjects/deep...
# 2  file:///mnt/0A2AAC152AABFBB7/sideProjects/deep...
# 3  file:///mnt/0A2AAC152AABFBB7/sideProjects/deep...
# 4  file:///mnt/0A2AAC152AABFBB7/sideProjects/deep...
#
#                         start_time                         end_time  \
# 0 2024-04-29 13:38:43.407000+00:00 2024-04-29 13:38:43.436000+00:00
# 1 2024-04-29 13:38:40.224000+00:00 2024-04-29 13:38:40.273000+00:00
# 2 2024-04-29 13:38:36.748000+00:00 2024-04-29 13:38:36.780000+00:00
# 3 2024-04-29 13:38:31.164000+00:00 2024-04-29 13:38:31.191000+00:00
# 4 2024-04-29 13:38:26.850000+00:00 2024-04-29 13:38:26.877000+00:00
#
#    metrics.loss  metrics.accuracy params.epochs params.hidden_activation  \
# 0      1.594560          0.617097             9                     relu
# 1      1.111658          0.747996             9                     relu
# 2      0.944035          0.794301             9                     relu
# 3      1.000223          0.768923             9                     relu
# 4      0.984594          0.771594             9                     relu
#
#   params.batch_size params.units_1st_layer params.units_2nd_layer  \
# 0               512                     64                     64
# 1               512                     64                     64
# 2               512                     64                     64
# 3               512                     64                     64
# 4               512                     64                     64
#
#   tags.mlflow.runName tags.mlflow.user tags.model  \
# 0     bright-wren-878         luisggon     Base_0
# 1     sincere-pig-226         luisggon     Base_0
# 2    valuable-roo-908         luisggon     Base_0
# 3      wise-smelt-437         luisggon     Base_0
# 4    puzzled-seal-143         luisggon     Base_0
#
#                              tags.mlflow.source.name tags.mlflow.source.type
# 0  /mnt/0A2AAC152AABFBB7/sideProjects/deepLearnin...                   LOCAL
# 1  /mnt/0A2AAC152AABFBB7/sideProjects/deepLearnin...                   LOCAL
# 2  /mnt/0A2AAC152AABFBB7/sideProjects/deepLearnin...                   LOCAL
# 3  /mnt/0A2AAC152AABFBB7/sideProjects/deepLearnin...                   LOCAL
# 4  /mnt/0A2AAC152AABFBB7/sideProjects/deepLearnin...                   LOCAL
